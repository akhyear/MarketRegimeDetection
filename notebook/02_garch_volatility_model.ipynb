# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from arch import arch_model

# %%
df = pd.read_csv("../data/market_regime_features.csv")
df.head()
# Out:
#          Date      Price     Close  log_return  volatility_20      ma_50  \
# 0  2010-10-19  88.830933 -0.013191    0.008330      84.982190  84.739096
# 1  2010-10-20  89.698502  0.009719    0.008407      85.074856  84.761324
# 2  2010-10-21  89.896339  0.002203    0.008067      85.218106  84.784240
# 3  2010-10-22  90.063728  0.001860    0.006869      85.374847  84.806193
# 4  2010-10-25  90.330109  0.002953    0.006711      85.541759  84.828052
#
#      ma_200     trend  momentum_10  drawdown
# 0  0.243094  0.005946    -0.031990       NaN
# 1  0.313533  0.015858    -0.022536       NaN
# 2  0.433866  0.019328    -0.020380       NaN
# 3  0.568654  0.015531    -0.018556       NaN
# 4  0.713708  0.017574    -0.015653       NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3868 entries, 0 to 3867
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3868 non-null   str
#  1   Price          3868 non-null   float64
#  2   Close          3868 non-null   float64
#  3   log_return     3868 non-null   float64
#  4   volatility_20  3868 non-null   float64
#  5   ma_50          3868 non-null   float64
#  6   ma_200         3868 non-null   float64
#  7   trend          3868 non-null   float64
#  8   momentum_10    3868 non-null   float64
#  9   drawdown       0 non-null      float64
# dtypes: float64(9), str(1)
# memory usage: 302.3 KB

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3868 entries, 0 to 3867
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3868 non-null   datetime64[us]
#  1   Price          3868 non-null   float64
#  2   Close          3868 non-null   float64
#  3   log_return     3868 non-null   float64
#  4   volatility_20  3868 non-null   float64
#  5   ma_50          3868 non-null   float64
#  6   ma_200         3868 non-null   float64
#  7   trend          3868 non-null   float64
#  8   momentum_10    3868 non-null   float64
#  9   drawdown       0 non-null      float64
# dtypes: datetime64[us](1), float64(9)
# memory usage: 302.3 KB
